# %% [markdown]
# ## MINI PROJECT REPORT: EDA AND STATISTIC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
df=pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## PART-B

# %% [markdown]
# ## QUES-1. Import the dataset and view the first 10 rows of it.

# %%
df=pd.read_csv('creditcard.csv')
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %% [markdown]
# ## QUES-2. Display shape/dimension of the dataset.

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ## QUES-3. Check for the missing values.Display number of missing values per column.

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## QUES-4.Check the datatype, number of non-null values and name of each variablein the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ## 5. Check if there are any non-real characters in the dataset.

# %%
df = pd.read_csv(creditcard.csv')
print(df.head(10)

# %% [markdown]
# ## QUES-6 Check the descriptive statistics of the dataset.

# %%
print(df.describe())
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ## 7. Check the number of fraudulent transactions in the dataset and visualizeusing pie chart and bar plot.

# %%
import pandas as pd  
import numpy as np
df= pd.read_csv('creditcard.csv')
print('The shape of the dataset is: ', df)

# %%
import matplotlib.pyplot as plt

# Count frauds
frauds = df['Class'].value_counts()
print(f'Number of Frauds: {frauds[1]}')

# Pie chart
labels = ['Legit', 'Fraud']
sizes = [frauds[0], frauds[1]]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Fraud vs Legit Transactions')
plt.show()

# Bar plot
frauds.plot(kind='bar', legend=False, figsize=(10,5))
plt.title('Distribution of Fraudulent Transactions')
plt.ylabel('Count')
plt.show()
# Out:
# Number of Frauds: 492

# %% [markdown]
# ## QUES-8. Check the maximum and minimum fraudulent amount.

# %%
fraud_transactions = df[df['Class'] == 1]
print(f'Minimum Fraudulent Amount: {fraud_transactions["Amount"].min()}')
print(f'Maximum Fraudulent Amount: {fraud_transactions["Amount"].max()}')s
# Out:
# Minimum Fraudulent Amount: 0.0
# Maximum Fraudulent Amount: 2125.87

# %% [markdown]
# ## QUES-13 List down columns that have high kurtosis.

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('creditcard.csv')

# Calculate kurtosis for each column
kurtosis_values = df.kurtosis()

# Display columns with high kurtosis
high_kurtosis_columns = kurtosis_values[abs(kurtosis_values) > 3]  # You can adjust the threshold as needed
print(high_kurtosis_columns)
# Out:
# V1         32.486679
# V2         95.773106
# V3         26.619551
# V5        206.904560
# V6         42.642494
# V7        405.607417
# V8        220.586974
# V9          3.731311
# V10        31.988239
# V12        20.241870
# V14        23.879462
# V16        10.419131
# V17        94.799719
# V20       271.016113
# V21       207.287040
# V23       440.088659
# V25         4.290412
# V27       244.989241
# V28       933.397502
# Amount    845.092646
# Class     573.887843
# dtype: float64

# %% [markdown]
# ## QUES-14. What is the distribution of Time and Amount columns in the dataset ?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('creditcard.csv')

# Plot histograms for 'Time' and 'Amount'
plt.figure(figsize=(12, 6))

# Plot for 'Time'
plt.subplot(1, 2, 1)
plt.hist(df['Time'], bins=50, color='blue', alpha=0.7)
plt.title('Distribution of Time')
plt.xlabel('Time')
plt.ylabel('Frequency')

# Plot for 'Amount'
plt.subplot(1, 2, 2)
plt.hist(df['Amount'], bins=50, color='green', alpha=0.7)
plt.title('Distribution of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Summary statistics for 'Time'
print("Summary statistics for 'Time':")
print(df['Time'].describe())

# Summary statistics for 'Amount'
print("\nSummary statistics for 'Amount':")
print(df['Amount'].describe())
# Out:
# Summary statistics for 'Time':
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64
#
# Summary statistics for 'Amount':
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# ## QUES- 15. Find the distribution of all variables with respect to the outcome ‘Class’ variable.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('creditcard.csv')

# Set the style for the plots
sns.set(style="whitegrid")

# Get the number of features (excluding 'Class' column)
num_features = len(df.columns) - 1

# Determine the number of rows and columns for subplots
num_rows = (num_features // 4) + 1
num_cols = min(num_features, 4)

# Plot distributions for each variable with respect to 'Class'
plt.figure(figsize=(15, 5 * num_rows))

# Loop through each column (excluding 'Class' column)
for i, column in enumerate(df.columns[:-1]):
    plt.subplot(num_rows, num_cols, i + 1)
    sns.kdeplot(df.loc[df['Class'] == 0, column], label='Non-Fraud', shade=True, color='b')
    sns.kdeplot(df.loc[df['Class'] == 1, column], label='Fraud', shade=True, color='r')
    plt.title(f'Distribution of {column} by Class')
    plt.xlabel(column)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\tiwar\AppData\Local\Temp\ipykernel_11312\1748020780.py:24: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['Class'] == 0, column], label='Non-Fraud', shade=True, color='b')
# C:\Users\tiwar\AppData\Local\Temp\ipykernel_11312\1748020780.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['Class'] == 1, column], label='Fraud', shade=True, color='r')
# C:\Users\tiwar\AppData\Local\Temp\ipykernel_11312\1748020780.py:24: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['Class'] == 0, column], label='Non-Fraud', shade=True, color='b')
# ...

# %%
# Summary statistics for each variable grouped by 'Class'
class_summary = df.groupby('Class').describe().transpose()
print(class_summary)

# %% [markdown]
# ## QUES-16 Create a countplot for the outcome class in seaborn using percentage instead of count for each bar

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('creditcard.csv')

# Calculate the percentage of each class
class_percentage = df['Class'].value_counts(normalize=True) * 100

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot with percentages
plt.figure(figsize=(6, 4))
ax = sns.countplot(x='Class', data=df, order=class_percentage.index, palette='viridis')

# Annotate each bar with its percentage value
total = len(df['Class'])
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 3, f'{height/total:.2%}', ha="center")

plt.title('Distribution of Outcome Class (Fraud vs Non-Fraud)')
plt.xlabel('Class')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# ## QUES-9 Check the number of transactions where the transaction amount is zeroand consider as a fraud transaction.

# %%
# Count the number of transactions where the transaction amount is zero and classify them as fraudulent transactions
fraudulent_zero_amount = df[(df['Amount'] == 0) & (df['Class'] == 1)]

# Get the count of fraudulent transactions with zero amount
num_fraudulent_zero_amount = len(fraudulent_zero_amount)

print(f"The number of fraudulent transactions with zero amount is: {num_fraudulent_zero_amount}")
# Out:
# The number of fraudulent transactions with zero amount is: 27

# %% [markdown]
# ## QUES-10 Check the distribution of columns. List down columns that are normally distributed . List down columns that are not normally distributed.

# %%
# List to store column names based on distribution
normally_distributed_cols = []
not_normally_distributed_cols = []

# Loop through columns and check their distribution
for col in df.columns:
    # Exclude non-numeric columns like 'Class'
    if col != 'Class':
        data = df[col]
        
        # Plot histogram for visualization
        plt.figure(figsize=(6, 4))
        plt.hist(data, bins=30, alpha=0.7)
        plt.title(f'Histogram of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.show()
        
        # Perform normality test (Shapiro-Wilk test)
        p_value = stats.shapiro(data)[1]
        
        # Set the significance level (alpha) for the test (commonly 0.05)
        alpha = 0.05
        
        # Check if p-value is less than alpha to determine normality
        if p_value > alpha:
            normally_distributed_cols.append(col)
        else:
            not_normally_distributed_cols.append(col)
print("Columns that are normally distributed:")
print(normally_distributed_cols)

print("\nColumns that are not normally distributed:")
print(not_normally_distributed_cols)
# Out:
# C:\Users\tiwar\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Columns that are normally distributed:
# []
#
# Columns that are not normally distributed:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %% [markdown]
# ## QUES-11 List down columns that are highly skewed.

# %%
# Assuming your dataset is stored in a DataFrame named 'data'
# Replace 'data' with the actual variable name containing your dataset

# Calculating skewness for numerical columns
skewness = data.skew()

# Set a threshold for skewness value to identify highly skewed columns
threshold = 1  # You can adjust this threshold based on your data characteristics

# Filtering columns with skewness above the threshold
highly_skewed_columns = skewness[abs(skewness) > threshold]

# Display highly skewed columns
print("Highly skewed columns:")
print(highly_skewed_columns)
# Out:
# Highly skewed columns:
# [16.97772445]

# %% [markdown]
# ## QUES-12. With the help of a standard scaler, normalize the respective column distribution

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Assuming your dataset is stored in a DataFrame named 'data'
# Replace 'data' with the actual variable name containing your dataset

# Check the numerical columns for normalization
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Create a DataFrame with only the numerical columns
data_numeric = df[numerical_columns]

# Initialize StandardScaler
scaler = StandardScaler()

# Normalize the numerical columns
data_normalized = scaler.fit_transform(data_numeric)

# Convert the normalized array back to a DataFrame
data_normalized = pd.DataFrame(data_normalized, columns=numerical_columns)

# Display the normalized DataFrame
print("Normalized DataFrame:")
print(data_normalized.head())
# Out:
# Normalized DataFrame:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.193679  0.082637  0.331128  ... -0.024923  0.382854 -0.176911  0.110507
# 1 -0.063700  0.071253 -0.232494  ... -0.307377 -0.880077  0.162201 -0.561131
# 2  0.639776  0.207373 -1.378675  ...  0.337632  1.063358  1.456320 -1.138092
# 3  0.192071  0.316018 -1.262503  ... -0.147443  0.007267 -0.304777 -1.941027
# 4  0.479302 -0.226510  0.744326  ... -0.012839  1.100011 -0.220123  0.233250
#
# ...

# %% [markdown]
# ## QUES-13. List down columns that have high kurtosis.

# %%
import pandas as pd

# Assuming your dataset is stored in a DataFrame named 'data'
# Replace 'data' with the actual variable name containing your dataset

# Calculating kurtosis for numerical columns
kurtosis_values = data.kurtosis()

# Set a threshold for kurtosis value to identify columns with high kurtosis
threshold = 3  # You can adjust this threshold based on your data characteristics

# Filtering columns with kurtosis above the threshold
high_kurtosis_columns = kurtosis_values[kurtosis_values > threshold]

# Display columns with high kurtosis
print("Columns with high kurtosis:")
print(high_kurtosis_columns)
# Out:
# Columns with high kurtosis:
# [845.09264555]

# %% [markdown]
# ## QUES-14 . What is the distribution of Time and Amount columns in the dataset?

# %%
import matplotlib.pyplot as plt

# Assuming your dataset is stored in a DataFrame named 'data'
# Replace 'data' with the actual variable name containing your dataset

# Visualize distribution of 'Time' column
plt.figure(figsize=(8, 5))
plt.hist(df['Time'], bins=50, color='skyblue')
plt.title('Distribution of Time')
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency')
plt.show()

# Visualize distribution of 'Amount' column
plt.figure(figsize=(8, 5))
plt.hist(df['Amount'], bins=50, color='salmon')
plt.title('Distribution of Amount')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.yscale('log')  # Using logarithmic scale for better visualization if needed
plt.show()

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('creditcard.csv')

# Display the first few rows of the DataFrame to verify the data is loaded
print(df.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## QUES-17. Plot a heatmap for correlation matrix for the given dataset. Write theObservation. Especially note down columns that are highly correlated (Positive and Negative Correlation, Consider 0.7 to 1 as high).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the dataset

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Set a threshold for correlation
threshold = 0.7  # Adjust as needed

# Create a mask to display only correlations above the threshold
mask = abs(correlation_matrix) > threshold
filtered_matrix = correlation_matrix[mask]

# Extract the indices and columns from the filtered matrix
selected_columns = filtered_matrix.columns.tolist()

# Filter the correlation matrix based on selected columns
clustered_matrix = correlation_matrix.loc[selected_columns, selected_columns]

# Plot a clustered heatmap
plt.figure(figsize=(12, 10))
sns.clustermap(clustered_matrix, cmap='coolwarm', annot=True, fmt=".2f", linewidths=.5)
plt.title('Clustered Heatmap of Correlation Matrix (Threshold: 0.7)')
plt.show()

# %% [markdown]
# ## QUES-18 With the help of hypothesis testing check whether fraudulent transactions of higher value than normal transactions?

# %%
from scipy.stats import ttest_ind

# Assuming 'df' is your DataFrame containing transaction data

# Extract transaction amounts for fraudulent and non-fraudulent transactions
fraudulent_amounts = df[df['Class'] == 1]['Amount']
non_fraudulent_amounts = df[df['Class'] == 0]['Amount']

# Perform the t-test
t_statistic, p_value = ttest_ind(fraudulent_amounts, non_fraudulent_amounts, alternative='greater')

# Set the significance level
alpha = 0.05

# Check for significance
if p_value < alpha:
    print("Reject the null hypothesis: There is evidence that fraudulent transactions have higher values.")
else:
    print("Fail to reject the null hypothesis: There is no evidence that fraudulent transactions have higher values.")
# Out:
# Reject the null hypothesis: There is evidence that fraudulent transactions have higher values.

# %% [markdown]
# # QUES-19) Perform ANOVA test for Statistical feature selection.

# %%
import pandas as pd
import numpy as np

# Assuming 'df' is your DataFrame containing the dataset
# Replace 'Categorical' and 'Numeric' with your actual column names

# Generate a sample DataFrame (replace this with your actual data loading)
data = {
    'Categorical': np.random.choice(['A', 'B', 'C'], size=100),
    'Numeric': np.random.randint(1, 100, size=100)
}
df = pd.DataFrame(data)

# Extract unique categories from the categorical column
categories = df['Categorical'].unique()

# Calculate group means
group_means = [df[df['Categorical'] == category]['Numeric'].mean() for category in categories]

# Overall mean of the numerical feature
overall_mean = df['Numeric'].mean()

# Calculate between-group variability (SSB)
SSB = sum([(df[df['Categorical'] == category]['Numeric'].mean() - overall_mean) ** 2 for category in categories])

# Calculate within-group variability (SSW)
SSW = sum([sum((df[df['Categorical'] == category]['Numeric'] - group_means[i]) ** 2) for i, category in enumerate(categories)])

# Degrees of freedom
df_between = len(categories) - 1
df_within = len(df) - len(categories)

# Calculate F-statistic
F_statistic = (SSB / df_between) / (SSW / df_within)

# Calculate p-value using F-distribution
from scipy.stats import f

p_value = 1 - f.cdf(F_statistic, df_between, df_within)

# Set significance level
alpha = 0.05

# Check for significance
if p_value < alpha:
    print("Reject the null hypothesis: There are significant differences in means across the categories.")
else:
    print("Fail to reject the null hypothesis: There are no significant differences in means across the categories.")
# Out:
# Fail to reject the null hypothesis: There are no significant differences in means across the categories.

# %% [markdown]
# ## QUES-20) Split the dataset randomly into train and test datasets. Use a train -testratio of 70:30 ratio.

# %%
import pandas as pd
import numpy as np

# Set the random seed for reproducibility
np.random.seed(42)

# Get the number of rows in the DataFrame
num_rows = len(df)

# Generate random indices based on the number of rows
random_indices = np.random.permutation(num_rows)

# Calculate the split index for train and test (70:30 ratio)
split_index = int(0.7 * num_rows)

# Split the indices into train and test sets
train_indices = random_indices[:split_index]
test_indices = random_indices[split_index:]

# Split the DataFrame into train and test sets using iloc
train_data = df.iloc[train_indices]
test_data = df.iloc[test_indices]

# Check the shapes of the resulting sets
print("Train set shape:", train_data.shape)
print("Test set shape:", test_data.shape)
# Out:
# Train set shape: (70, 2)
# Test set shape: (30, 2)

# %%
import matplotlib.pyplot as plt

# Assuming 'train_data' and 'test_data' are your train and test datasets

# Get the shapes of the train and test datasets
train_shape = train_data.shape
test_shape = test_data.shape

# Create lists for plotting
labels = ['Train Data', 'Test Data']
sizes = [train_shape[0], test_shape[0]]

# Plotting the bar chart
plt.figure(figsize=(8, 6))
plt.bar(labels, sizes, color=['blue', 'green'])
plt.xlabel('Dataset')
plt.ylabel('Number of Samples')
plt.title('Shape of Train and Test Datasets')
plt.show()

# %% [markdown]
# ## PART-A

# %% [markdown]
# The following are the ages of CEOs of 42 Top Fortune 500 Companies when they took over the post of CEO
# 57 61 57 57 58 57 61 54 68
# 51 49 64 50 48 65 52 56 46
# 54 49 50 47 55 55 54 42 51
# 56 55 54 51 60 62 43 55 56
# 61 52 69 64 46 54
# Use this data for answering following questions where relevant

# %% [markdown]
# ## QUES-1 Compute the mean, median and the mode of the data

# %%
import pandas as pd
import numpy as np
from scipy import stats 
# Create a pandas dataframe
df = pd.DataFrame({'CEO Ages': [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 
                                48, 65, 52, 56, 46, 54, 49, 50, 47, 55, 55, 54, 42, 
                                51, 56, 55, 54, 51, 60, 62, 43, 55, 56, 61, 52, 69, 
                                64, 46, 54]})
df
# Out:
#     CEO Ages
# 0         57
# 1         61
# 2         57
# 3         57
# 4         58
# 5         57
# 6         61
# 7         54
# 8         68
# 9         51
# 10        49
# 11        64
# 12        50
# 13        48
# 14        65
# 15        52
# 16        56
# 17        46
# 18        54
# 19        49
# 20        50
# 21        47
# 22        55
# 23        55
# 24        54
# 25        42
# 26        51
# 27        56
# 28        55
# 29        54
# 30        51
# 31        60
# 32        62
# 33        43
# 34        55
# 35        56
# 36        61
# 37        52
# 38        69
# 39        64
# 40        46
# 41        54

# %%
# Mean
mean = df['CEO Ages'].mean()
mean
# Out:
# 54.904761904761905

# %%
# Median
median = df['CEO Ages'].median()
median
# Out:
# 55.0

# %%
# Mode
mode = df['CEO Ages'].mode()
mode
# Out:
# 0    54
# Name: CEO Ages, dtype: int64

# %%
print(f"Mean: {mean}, Median: {median}")
# Out:
# Mean: 54.904761904761905, Median: 55.0

# %% [markdown]
# ## QUES-2 Compute the range , variance and standard deviation of CEO ages

# %%
# Range
range_data = df['CEO Ages'].max() - df['CEO Ages'].min()
range_data
# Out:
# 27

# %%
# Variance
variance = df['CEO Ages'].var()
variance
# Out:
# 39.4541231126597

# %%
# Standard Deviation
std_dev = df['CEO Ages'].std()
std_dev
# Out:
# 6.2812517154353635

# %%
print(f"Range: {range_data}, Variance: {variance}, Standard Deviation: {std_dev}")
# Out:
# Range: 27, Variance: 39.4541231126597, Standard Deviation: 6.2812517154353635

# %% [markdown]
# ## QUES-3. Find the mean deviation for the data . The mean deviation is defined asbelow.

# %%
import matplotlib.pyplot as plt
import numpy as np

ages_of_CEOs = [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 48, 65, 52, 56, 46,
        54, 49, 50, 47, 55, 55, 54, 42, 51, 56, 55, 54, 51, 60, 62, 43, 55, 56,
        61, 52, 69, 64, 46, 54]
# calculate mean deviation
mean_age=np.mean(ages_of_CEOs)
mean_deviation=np.mean(np.abs(ages_of_CEOs - mean_age))
print(f"The mean deviation for the given data is:', {mean_deviation:.4f}")
# Out:
# The mean deviation for the given data is:', 4.8141

# %% [markdown]
# ## QUES-4 Calculate the Pearson coefficient of skewness and comment on theskewness of the data.

# %%
# Calculate the Pearson Coefficient of Skewness
median_age=np.median(ages_of_CEOs)
stSd_dev_age=np.std(ages_of_CEOs)

skewness=3* (mean_age - median_age)/std_dev_age

print(f"The Pearson coefficient of skewness for the given data is: {skewness:.4f}")
# Out:
# The Pearson coefficient of skewness for the given data is: -0.0460

# %% [markdown]
# ## QUES-5 Count the  number of data values that fall within two standard deviations ofthe mean. Compare this with the answer from Chebyshev’s Theorem.

# %%
import pandas as pd
import numpy as np
from scipy import stats 
# Create a pandas dataframe
df = pd.DataFrame({'CEO Ages': [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 48, 65, 52, 56,
                                46, 54, 49, 50, 47, 55, 55, 54, 42, 51, 56, 55, 54, 51, 60, 62, 43, 
                                55, 56, 61, 52, 69, 64, 46, 54]})
# Mean
mean = df['CEO Ages'].mean()

# Median
median = df['CEO Ages'].median()


# Range
range_data = df['CEO Ages'].max() - df['CEO Ages'].min()

# Variance
variance = df['CEO Ages'].var()

# Standard Deviation
std_dev = df['CEO Ages'].std()


print(f"Mean: {mean}, Median: {median}")
print(f"Range: {range_data}, Variance: {variance}, Standard Deviation: {std_dev}")
# Out:
# Mean: 54.904761904761905, Median: 55.0
# Range: 27, Variance: 39.4541231126597, Standard Deviation: 6.2812517154353635

# %%
# Count number of values within two standard deviations
count = df['CEO Ages'].between(mean - 2*std_dev, mean + 2*std_dev).sum()

print(f"Number of values within two standard deviations: {count}")
# Out:
# Number of values within two standard deviations: 39

# %% [markdown]
# ## QUES-6. Find the three quartiles and the interquartile range (IQR).

# %%
# Quartiles
q1 = df['CEO Ages'].quantile(0.25)
q2 = df['CEO Ages'].quantile(0.5)
q3 = df['CEO Ages'].quantile(0.75)

# Interquartile Range
iqr = q3 - q1

print(f"Q1: {q1}, Q2 (median): {q2}, Q3: {q3}. Interquartile Range (IQR): {iqr}")
# Out:
# Q1: 51.0, Q2 (median): 55.0, Q3: 57.75. Interquartile Range (IQR): 6.75

# %% [markdown]
# ## QUES-7 Are there any outliers in the data set ?

# %%
import matplotlib.pyplot as plt
import numpy as np

ages = [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 48, 65, 52, 56, 46, 54, 49, 50, 47, 55, 55, 54, 42, 51, 56, 55, 54, 51, 60, 62, 43, 55, 56, 61, 52, 69, 64, 46, 54]


Q1 = np.percentile(ages, 25)
Q3 = np.percentile(ages, 75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

outliers = []
for age in ages:
    if age < lower_bound or age > upper_bound:
        outliers.append(age)

print("Outliers:", outliers)

# Create a boxplot to visualize the outliers
plt.boxplot(ages)
plt.show()
# Out:
# Outliers: [68, 69]

# %% [markdown]
# ## QUES-8 Draw a boxplot of the dataset to confirm .

# %%
# draw a boxplot of the dataset

import matplotlib.pyplot as plt

# Replace these with the actual data you have
data = [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 48, 65, 52, 56, 46, 54, 49, 50, 47, 55, 55, 54, 42, 51, 56, 55, 54, 51, 60, 62, 43, 55, 56, 61, 52, 69, 64, 46, 54]

plt.boxplot(data)
plt.title('Boxplot of Ages of CEOs when they took over')
plt.xlabel('Dataset')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Q9. Find the percentile rank of the datapoint 50

# %%
import numpy as np

# CEO ages dataset
ceo_ages = np.array([57, 61, 57, 57, 58, 57, 61, 54, 68,
                     51, 49, 64, 50, 48, 65, 52, 56, 46,
                     54, 49, 50, 47, 55, 55, 54, 42, 51,
                     56, 55, 54, 51, 60, 62, 43, 55, 56,
                     61, 52, 69, 64, 46, 54])

# Calculate the percentile rank of the data point 50
percentile_rank = np.percentile(ceo_ages, np.sum(ceo_ages <= 50) * 100 / len(ceo_ages))

print(f"The percentile rank of the datapoint 50 is: {percentile_rank:.2f}")
# Out:
# The percentile rank of the datapoint 50 is: 50.76

# %% [markdown]
# ## QUES-10. What is the probability that a person becoming a CEO is below 50 yearsof age ?

# %%
# CEO ages dataset
ceo_ages = np.array([57, 61, 57, 57, 58, 57, 61, 54, 68,
                     51, 49, 64, 50, 48, 65, 52, 56, 46,
                     54, 49, 50, 47, 55, 55, 54, 42, 51,
                     56, 55, 54, 51, 60, 62, 43, 55, 56,
                     61, 52, 69, 64, 46, 54])

# Count the number of CEOs below 50 years of age
ceos_below_50 = sum(age < 50 for age in ceo_ages)

# Total number of CEOs in the dataset
total_ceos = len(ceo_ages)

# Calculate the probability that a person becoming a CEO is below 50 years of age
probability_below_50 = ceos_below_50 / total_ceos

print(f"The probability that a person becoming a CEO is below 50 years of age is: {probability_below_50:.2f}")
# Out:
# The probability that a person becoming a CEO is below 50 years of age is: 0.19

# %% [markdown]
# ## QUES-11. Create a frequency distribution for the data and visualize it appropriately

# %%
import matplotlib.pyplot as plt
import numpy as np

# CEO ages dataset
ceo_ages = np.array([57, 61, 57, 57, 58, 57, 61, 54, 68,
                     51, 49, 64, 50, 48, 65, 52, 56, 46,
                     54, 49, 50, 47, 55, 55, 54, 42, 51,
                     56, 55, 54, 51, 60, 62, 43, 55, 56,
                     61, 52, 69, 64, 46, 54])

# Calculate the minimum and maximum ages to define bins for the histogram
min_age = min(ceo_ages)
max_age = max(ceo_ages)

# Define the number of bins for the histogram (can be adjusted)
num_bins = max_age - min_age + 1

# Create a histogram for CEO ages
plt.figure(figsize=(8, 5))
plt.hist(ceo_ages, bins=num_bins, color='skyblue', edgecolor='black')
plt.title('Frequency Distribution of CEO Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.xticks(np.arange(min_age, max_age+1, 1))  # Set x-axis ticks for each age
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## QUES-12 Create a probability distribution of the data and visualize it appropriately

# %%
import matplotlib.pyplot as plt
import numpy as np

# CEO ages dataset
ceo_ages = np.array([57, 61, 57, 57, 58, 57, 61, 54, 68,
                     51, 49, 64, 50, 48, 65, 52, 56, 46,
                     54, 49, 50, 47, 55, 55, 54, 42, 51,
                     56, 55, 54, 51, 60, 62, 43, 55, 56,
                     61, 52, 69, 64, 46, 54])

# Calculate the minimum and maximum ages to define bins for the histogram
min_age = min(ceo_ages)
max_age = max(ceo_ages)

# Define the number of bins for the histogram (can be adjusted)
num_bins = max_age - min_age + 1

# Create a normalized histogram for CEO ages (probability distribution)
plt.figure(figsize=(8, 5))
plt.hist(ceo_ages, bins=num_bins, density=True, color='skyblue', edgecolor='black')
plt.title('Probability Distribution of CEO Ages')
plt.xlabel('Age')
plt.ylabel('Probability Density')
plt.xticks(np.arange(min_age, max_age+1, 1))  # Set x-axis ticks for each age
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## QUES-13 What is the shape of the distribution of this dataset? Create an appropriate graph to determine that. Take 100 random samples with replacement from this dataset of size 5 each.Createasampling distribution of the mean age of customers. Compare with other sampling distributions of sample size 10, 15, 20, 25, 30. State your observations. Does it corroborate the Central Limit Theorem?

# %%
import pandas as pd

# Provided data
ages_of_ceos = [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 48, 65, 52, 56, 46,
                54, 49, 50, 47, 55, 55, 54, 42, 51, 56, 55, 54, 51, 60, 62, 43, 55, 56,
                61, 52, 69, 64, 46, 54]

# Create a DataFrame
ceo_df = pd.DataFrame({'Age': ages_of_ceos})

# Display the DataFrame
print(ceo_df)
# Out:
#     Age
# 0    57
# 1    61
# 2    57
# 3    57
# 4    58
# 5    57
# 6    61
# 7    54
# 8    68
# 9    51
# 10   49
# 11   64
# 12   50
# 13   48
# 14   65
# 15   52
# 16   56
# 17   46
# 18   54
# 19   49
# 20   50
# 21   47
# 22   55
# 23   55
# 24   54
# 25   42
# 26   51
# 27   56
# 28   55
# 29   54
# 30   51
# 31   60
# 32   62
# 33   43
# 34   55
# 35   56
# 36   61
# 37   52
# 38   69
# 39   64
# 40   46
# 41   54

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(ceo_df['Age'], bins=10, edgecolor='black')
plt.title('Distribution of CEO Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Sampling Distribution and Central Limit Theorem (CLT):
#Sampling Distribution Code for Different Sample Sizes:
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Number of random samples
num_samples = 100

# Sample sizes to compare
sample_sizes = [5, 10, 15, 20, 25, 30]

# Create a dictionary to store sampling distributions
sampling_distributions = {}

# Generate sampling distributions for different sample sizes
for size in sample_sizes:
    means = [ceo_df['Age'].sample(size, replace=True).mean() for _ in range(num_samples)]
    sampling_distributions[size] = means

# Plot sampling distributions
plt.figure(figsize=(12, 8))

for size, means in sampling_distributions.items():
    plt.hist(means, bins=20, alpha=0.5, label=f'Sample Size {size}')

plt.title('Sampling Distributions of Mean CEO Age')
plt.xlabel('Mean Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## QUES-14. Treat this dataset as a binomial distribution where p is the probability that a person becomes a CEO above 50 years age. What is the probability that out of a random sample of 10 CEOs of Fortune 500 companies exactly 6 are above 50 years of age?

# %%
from scipy.stats import binom

# Define the dataset
ceo_df = pd.DataFrame({'Age': ages_of_ceos})

# Calculate the probability of success (p)
p = (ceo_df['Age'] > 50).mean()

# Define the parameters for the binomial distribution
n = 10  # number of trials (sample size)
k = 6   # number of successes

# Calculate the probability using the binomial distribution formula
probability_6_successes = binom.pmf(k, n, p)

print(f"The probability that exactly 6 out of 10 CEOs are above 50 years of age is approximately: {probability_6_successes:.4f}")
# Out:
# The probability that exactly 6 out of 10 CEOs are above 50 years of age is approximately: 0.1320

# %% [markdown]
# ## QUES-15. A study claims that 25% of all Fortune 500 companies becoming a CEO are above 60 years of age. Using the Normal approximation of a Binomial distribution, find the probability that in a random sample of 300 Fortune 500 companies exactly 75 CEOs will be above 50 years of age. [ Note that the normal distribution can be used to approximate a binomial distribution if np>=5 and nq>=5 with the following correction for continuity P(X=z) = P(z-0.5 < X < z+0.5 ) ]from scipy.stats import norm.

# %%
from scipy.stats import norm

# Given values
p = 0.25  # probability of success
n = 300   # number of trials (sample size)
k = 75    # number of successes

# Calculate np and npq
np_value = n * p
npq_value = n * p * (1 - p)

# Calculate the probability using the normal approximation
z_lower = (k - np_value) / (npq_value**0.5)
z_upper = (k + 0.5 - np_value) / (npq_value**0.5)

# Use the correction for continuity
probability_normal_approximation = norm.cdf(z_upper) - norm.cdf(z_lower)

print(f"The probability that exactly 75 CEOs out of 300 are above 50 years of age is approximately: {probability_normal_approximation:.4f}")
# Out:
# The probability that exactly 75 CEOs out of 300 are above 50 years of age is approximately: 0.0266

# %% [markdown]
# ## Q16. Compute a 95% Confidence Interval for the true mean age of the population of CEOs for the given dataset using appropriate distribution.( State reasons as to why did you use a z or t distribution)

# %%
import scipy.stats as stats
import numpy as np
from scipy.stats import t

# Sample statistics
sample_mean = np.mean(ages_of_ceos)
sample_std = np.std(ages_of_ceos, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(ages_of_ceos)

# Degrees of freedom for t-distribution
degrees_of_freedom = sample_size - 1

# Confidence level and alpha
confidence_level = 0.95
alpha = 1 - confidence_level

# Calculate the critical value from the t-distribution
t_critical = t.ppf(1 - alpha/2, degrees_of_freedom)

# Calculate the margin of error
margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))

# Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print(f"The 95% confidence interval for the true mean age of CEOs is: {confidence_interval}")
# Out:
# The 95% confidence interval for the true mean age of CEOs is: (52.94738608388915, 56.86213772563466)

# %% [markdown]
# ## QUES-17  A data scientist wants to estimate with 95% confidence the proportion ofCEOs of Fortune 500 companies are above 60 years in the population.Another recent study showed that 25% of CEOs interviewed were above 60. The data scientist wants to be accurate within 2% of the true proportion. Find theminimum sample size necessary.

# %%
from scipy.stats import norm

# Z-score for 95% confidence
confidence_level = 0.95
Z = norm.ppf((1 + confidence_level) / 2)  # Two-tailed

print(f"The Z-score for a 95% confidence level is approximately {Z:.2f}")

# Estimated proportion
p = 0.25
print(f"The estimated proportion of CEOs above 60 is {p}")

# Margin of error
E = 0.02
print(f"The margin of error is {E}")
# Out:
# The Z-score for a 95% confidence level is approximately 1.96
# The estimated proportion of CEOs above 60 is 0.25
# The margin of error is 0.02

# %% [markdown]
# Now try to estimate the proportion of CEOs above 60 with a 95% confidence level and an accuracy within 2% of the true proportion.

# %%
import numpy as np

# Given values
Z = 1.96  # Z-score for 95% confidence
p = 0.25  # Estimated proportion
E = 0.02  # Margin of error

# Calculate sample size
sample_size = ((Z ** 2) * p * (1 - p)) / (E ** 2)
print(f"The minimum sample size necessary is approximately {np.ceil(sample_size)}")
# Out:
# The minimum sample size necessary is approximately 1801.0

# %% [markdown]
# ## QUES-18  The same data scientist wants to estimate the true proportion of CEOs ascending to the post and above 60 years.She wants to be 90% confident and accurate within 5% of true proportion. Find the minimum sample size necessary.

# %%
# Z-score for 90% confidence
confidence_level = 0.90
Z_90 = norm.ppf((1 + confidence_level) / 2)  # Two-tailed

print(f"The Z-score for a 90% confidence level is approximately {Z_90:.2f}")

# Estimated proportion (using a conservative value for maximum variability)
p = 0.5
print(f"The estimated proportion (conservative) of CEOs above 60 is {p}")

# Margin of error (required accuracy within 5% of true proportion)
E_90 = 0.05
print(f"The margin of error is {E_90}")

# Calculate sample size
sample_size_90 = ((Z_90 ** 2) * p * (1 - p)) / (E_90 ** 2)
print(f"The minimum sample size necessary for 90% confidence is approximately {np.ceil(sample_size_90)}")
# Out:
# The Z-score for a 90% confidence level is approximately 1.64
# The estimated proportion (conservative) of CEOs above 60 is 0.5
# The margin of error is 0.05
# The minimum sample size necessary for 90% confidence is approximately 271.0

# %% [markdown]
# ## QUES-19 A researcher claims that currently 25% of all CEOS are above 60 years .Test his claim with an alpha =0.05 if out of a random sample of 30 CEOs only10 are above 60 years.

# %%
from scipy.stats import norm

# Given data
sample_size = 30
observed_above_60 = 10
claimed_proportion = 0.25  # 25% claimed proportion
alpha = 0.05

# Calculate sample proportion
sample_proportion = observed_above_60 / sample_size

# Calculate standard error
standard_error = (claimed_proportion * (1 - claimed_proportion) / sample_size) ** 0.5

# Calculate Z-score
Z = (sample_proportion - claimed_proportion) / standard_error

# Calculate critical Z-values
critical_value_left = norm.ppf(alpha / 2)
critical_value_right = norm.ppf(1 - alpha / 2)

print(f"Z-score: {Z:.2f}")
print(f"Critical values: {critical_value_left:.2f} and {critical_value_right:.2f}")

# Check if Z-score falls in the critical region or calculate p-value
if Z < critical_value_left or Z > critical_value_right:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Z-score: 1.05
# Critical values: -1.96 and 1.96
# Fail to reject the null hypothesis

# %% [markdown]
# ## QUES-20

# %%
"""20)
a. Hypotheses
1) Null Hypothesis (H0): The average CEO age in the UK is the same as the average CEO age in the USA.
μ (UK)=μ (USA)
2) Alternative Hypothesis (H1): The average CEO age in the UK is older than the average CEO age in the USA.

b. Significance Level
1) The significance level is the threshold for accepting or rejecting the null hypothesis. Common values are 0.05 or 0.01, denoted as α.
2) Let's use a significance level of α=0.05 for this test.

c. Statistical Test
Since we are comparing the means of two independent samples from different populations (UK and USA),
a two-sample t-test for independent samples will be appropriate."""

"""d. Test Results
1) To perform the t-test, we need sample means, sample standard deviations, and sample sizes for both the UK and USA.
Given the data provided:
UK sample size (n1) = 40
USA sample size (n2) = 40

Given s1 = 8.8 and s2 = 7.8
"""
import numpy as np
from scipy.stats import t

# Given data
UK_data = np.array([47, 49, 73, 50, 65, 70, 49, 47, 40, 43, 46, 35, 38, 40, 47, 39, 49, 37, 37, 36,
                    40, 37, 31, 48, 48, 45, 52, 38, 38, 36, 44, 40, 48, 45, 45, 36, 39, 44, 52, 47])
USA_data = np.array([47, 57, 52, 47, 48, 56, 56, 52, 50, 40, 46, 43, 44, 51, 36, 42, 49, 49, 40, 43,
                     39, 39, 22, 41, 45, 46, 39, 32, 36, 32, 32, 37, 33, 44, 49, 44, 44, 49, 32])

# Sample statistics
n1 = len(UK_data)
n2 = len(USA_data)
mean_UK = np.mean(UK_data)
mean_USA = np.mean(USA_data)
s1 = 8.8
s2 = 7.8

# Calculate t-test statistic
SE = np.sqrt((s1**2 / n1) + (s2**2 / n2))
t_statistic = (mean_UK - mean_USA) / SE

# Degrees of freedom
df = n1 + n2 - 2

# Calculate critical t-value for one-tailed test at alpha = 0.05
alpha = 0.05
critical_t_value = t.ppf(1 - alpha, df)

print(f"T-test statistic: {t_statistic:.2f}")
print(f"Critical t-value: {critical_t_value:.2f}")
# Out:
# T-test statistic: 0.85
# Critical t-value: 1.66

# %% [markdown]
# ## e. Decision
#  1)If the t-test statistic is greater than the critical t-value, we reject the null hypothesis.
#  2)If the t-test statistic is less than the critical t-value, we fail to reject the null hypothesis.
# ## f. Conclusion
#  Based on the comparison between the t-test statistic and the critical t-value,
#  make a decision to either reject or fail to reject the null hypothesis.
#
# ## g.Data Analysis
# The data provided gives us a starting point,
# but more comprehensive demographic information and a larger sample size might provide more conclusive results.
#
# ## h.Other Data
# To better answer the question, additional information like CEO tenure, company size, industry,
# and regional economic factors could be considered for a more comprehensive analysis."""
